# %% [markdown]
# <a href="https://colab.research.google.com/github/r4kn0s/Bootcamp-Keepcoding/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# mi primer codigo de  IA

# %%
import numpy as np
print("Hola World")
# Out:
# Hola World

# %%
datos = [1, 2, 3, 4, 5]
media = np.mean(datos)
print(f"la media es : {media}")
# Out:
# la media es : 3.0
